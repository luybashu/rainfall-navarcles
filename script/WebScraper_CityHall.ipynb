# %% [markdown]
# # Cityhall Data
#
# This script downloads data from Navarcles Cityhall webpage www.navarcles.cat.
# There are monthly data with daily resolution from 2008 in the form of .TXT files (for example, meteo_navarcles_202301.TXT).
#
# Txt files can be in different places, for example:
#
# - https://www.navarcles.cat/media/repository/meteo_navarcles_202303.TXT
# - https://www.navarcles.cat/media/repository/publicacions/meteo/2023/meteo_navarcles_202301.TXT

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
# base URL
BASE_URL = "https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics"
TXT_BASE_URL = "https://www.navarcles.cat/media/repository/publicacions/meteo/"

# %%
# directory to save the downloaded files
SAVE_DIR = os.path.join('..', 'data', 'navarcles_cityhall_data')
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
# find all "year" links from base url

response = requests.get(BASE_URL)
if response.status_code != 200:
    print("Failed to fetch the main page.")
    exit()

# parse the main page
soup = BeautifulSoup(response.text, "html.parser")

# {year: link}
year_links = {}
for link in soup.find_all("a", href=True):
    href = link["href"]
    if "resums-climatologics-" in href and href.endswith(".html"):
        year = href.split("-")[-1].split(".")[0]  # extract year from URL
        year_links[year] = urljoin(BASE_URL, href)

# %%
year_links
# Out:
# {'2025': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2025.html',
#  '2024': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2024.html',
#  '2023': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2023.html',
#  '2022': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2022.html',
#  '2021': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2021.html',
#  '2020': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2020.html',
#  '2019': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2019.html',
#  '2018': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2018.html',
#  '2017': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2017.html',
#  '2016': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2016.html',
#  '2015': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2015.html',
#  '2014': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2014.html',
#  '2013': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2013.html',
#  '2012': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2012.html',
#  '2011': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2011.html',
#  '2010': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2010.html',
#  '2009': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2009.html',
#  '2008': 'https://www.navarcles.cat/el-municipi/informacio-meteorologica/resums-climatologics/resums-climatologics-2008.html'}

# %%
# iterate over each yearly summary page
for year, year_link in year_links.items():
    print(f"Fetching data for {year}...")

    year_response = requests.get(year_link)
    if year_response.status_code != 200:
        print(f"Failed to fetch year {year}.")
        continue

    # Parse yearly summary page
    year_soup = BeautifulSoup(year_response.text, "html.parser")

    # Find all possible links to .txt files
    txt_links = []
    for file_link in year_soup.find_all("a", href=True):
        href = file_link["href"]
        if "media/repository/" in href and href.lower().endswith(".txt"):
            full_url = urljoin("https://www.navarcles.cat", href)
            txt_links.append(full_url)
    print(f"{year} has {len(txt_links)} files")

    for txt_link in txt_links:
        file_name = os.path.basename(txt_link)
        file_path = os.path.join(SAVE_DIR, file_name)
    
        # Download file
        file_response = requests.get(txt_link)
        if file_response.status_code == 200:
            with open(file_path, "wb") as f:
                f.write(file_response.content)
            print(f"Downloaded: {file_name}")
        else:
            print(f"Failed to download {file_name}")

print("All files downloaded successfully.")
# Out:
# Fetching data for 2025...
# 2025 has 1 files
# Downloaded: meteo_navarcles_202501.TXT
# Fetching data for 2024...
# 2024 has 12 files
# Downloaded: meteo_navarcles_202401.TXT
# Downloaded: meteo_navarcles_202402.TXT
# Downloaded: meteo_navarcles_202403.TXT
# Downloaded: meteo_navarcles_202404.TXT
# Downloaded: meteo_navarcles_202405.TXT
# Downloaded: meteo_navarcles_202406.TXT
# Downloaded: meteo_navarcles_202407.TXT
# Downloaded: meteo_navarcles_202408.TXT
# Downloaded: meteo_navarcles_202409.TXT
# Downloaded: meteo_navarcles_202410.TXT
# Downloaded: meteo_navarcles_202411.TXT
# Downloaded: meteo_navarcles_202412.TXT
# Fetching data for 2023...
# 2023 has 12 files
# Downloaded: meteo_navarcles_202301.TXT
# Downloaded: meteo_navarcles_202302.TXT
# Downloaded: meteo_navarcles_202303.TXT
# Downloaded: meteo_navarcles_202304.txt
# Downloaded: meteo_navarcles_202305.TXT
# Downloaded: meteo_navarcles-202306.TXT
# Downloaded: meteo_navarcles_202307.TXT
# Downloaded: meteo_navarcles_202308.TXT
# Downloaded: meteo_navarcles_202309.TXT
# Downloaded: meteo_navarcles_202310.TXT
# Downloaded: meteo_navarcles_202311.TXT
# Downloaded: meteo_navarcles_202312.TXT
# Fetching data for 2022...
# 2022 has 12 files
# Downloaded: meteo_navarcles_202201.TXT
# Downloaded: meteo_navarcles_202202.TXT
# Downloaded: meteo_navarcles_202203.TXT
# Downloaded: meteo_navarcles_202204.TXT
# Downloaded: meteo_navarcles_202205.TXT
# Downloaded: meteo_navarcles_202206.TXT
# Downloaded: meteo_navarcles_202207.TXT
# Downloaded: meteo_navarcles_202208.TXT
# Downloaded: meteo_navarcles_202209.TXT
# Downloaded: meteo_navarcles_202210.TXT
# Downloaded: meteo_navarcles_202211.TXT
# Downloaded: meteo_navarcles_202212.TXT
# Fetching data for 2021...
# 2021 has 12 files
# Downloaded: meteo_navarcles_202101.txt
# Downloaded: meteo_navarcles_202102.txt
# Downloaded: meteo_navarcles_202103.TXT
# Downloaded: meteo_navarcles_202104.TXT
# Downloaded: meteo_navarcles_202105.TXT
# Downloaded: meteo_navarcles_202106.TXT
# Downloaded: meteo_navarcles_202107.TXT
# Downloaded: meteo_navarcles_202108.TXT
# Downloaded: meteo_navarcles_202109.TXT
# Downloaded: meteo_navarcles_202110.TXT
# Downloaded: meteo_navarcles_202111.TXT
# Downloaded: meteo_navarcles_202112.TXT
# Fetching data for 2020...
# 2020 has 13 files
# Downloaded: meteo_navarcles_2020.txt
# Downloaded: meteo_navarcles_202001.txt
# Downloaded: meteo_navarcles_202002.txt
# Downloaded: meteo_navarcles_202003.txt
# Downloaded: meteo_navarcles_202004.txt
# Downloaded: meteo_navarcles_202005.txt
# Downloaded: meteo_navarcles_202006.txt
# Downloaded: meteo_navarcles_202007.txt
# Downloaded: meteo_navarcles_202008.txt
# Downloaded: meteo_navarcles_202009.txt
# Downloaded: meteo_navarcles_202010.txt
# Downloaded: meteo_navarcles_202011.txt
# Downloaded: meteo_navarcles_202012.txt
# Downloaded: meteo_navarcles_201507.txt
# Downloaded: meteo_navarcles_201508.txt
# Downloaded: meteo_navarcles_201509.txt
# Downloaded: meteo_navarcles_201510.txt
# Downloaded: meteo_navarcles_201511.txt
# Downloaded: meteo_navarcles_201512.txt
# Fetching data for 2014...
# 2014 has 13 files
# Downloaded: meteo_navarcles_2014.txt
# Downloaded: meteo_navarcles_201401.txt
# Downloaded: meteo_navarcles_201402.txt
# Downloaded: meteo_navarcles_201403.txt
# Downloaded: meteo_navarcles_201404.txt
# Downloaded: meteo_navarcles_201405.txt
# Downloaded: meteo_navarcles_201406.txt
# Downloaded: meteo_navarcles_201407.txt
# Downloaded: meteo_navarcles_201408.txt
# Downloaded: meteo_navarcles_201409.txt
# Downloaded: meteo_navarcles_201410.txt
# Downloaded: meteo_navarcles_201411.txt
# Downloaded: meteo_navarcles_201412.txt
# Fetching data for 2013...
# 2013 has 13 files
# Downloaded: meteo_navarcles_2013.txt
# Downloaded: meteo_navarcles_201301.txt
# Downloaded: meteo_navarcles_201302.txt
# Downloaded: meteo_navarcles_201303.txt
# Downloaded: meteo_navarcles_201304.txt
# Downloaded: meteo_navarcles_201305.txt
# Downloaded: meteo_navarcles_201306.txt
# Downloaded: meteo_navarcles_201307.txt
# Downloaded: meteo_navarcles_201308.txt
# Downloaded: meteo_navarcles_201309.txt
# Downloaded: meteo_navarcles_201310.txt
# Downloaded: meteo_navarcles_201311.txt
# Downloaded: meteo_navarcles_201312.txt
# Fetching data for 2012...
# 2012 has 13 files
# Downloaded: meteo_navarcles_2012.txt
# Downloaded: meteo_navarcles_201201.txt
# Downloaded: meteo_navarcles_201202.txt
# Downloaded: meteo_navarcles_201203.txt
# Downloaded: meteo_navarcles_201204.txt
# Downloaded: meteo_navarcles_201205.txt
# Downloaded: meteo_navarcles_201206.txt
# Downloaded: meteo_navarcles_201207.txt
# Downloaded: meteo_navarcles_201208.txt
# Downloaded: meteo_navarcles_201209.txt
# Downloaded: meteo_navarcles_201210.txt
# Downloaded: meteo_navarcles_201211.txt
# Downloaded: meteo_navarcles_201212.txt
# Fetching data for 2011...
# 2011 has 13 files
# Downloaded: meteo_navarcles_2011.txt
# Downloaded: meteo_navarcles_201101.txt
# Downloaded: meteo_navarcles_201102.txt
# Downloaded: meteo_navarcles_201103.txt
# Downloaded: meteo_navarcles_201104.txt
# Downloaded: meteo_navarcles_201105.txt
# Downloaded: meteo_navarcles_201106.txt
# Downloaded: meteo_navarcles_201107.txt
# Downloaded: meteo_navarcles_201108.txt
# Downloaded: meteo_navarcles_201109.txt
# Downloaded: meteo_navarcles_201110.txt
# Downloaded: meteo_navarcles_201111.txt
# Downloaded: meteo_navarcles_201112.txt
# Fetching data for 2010...
# 2010 has 13 files
# Downloaded: meteo_navarcles_2010.txt
# Downloaded: meteo_navarcles_201001.txt
# Downloaded: meteo_navarcles_201002.txt
# Downloaded: meteo_navarcles_201003.txt
# Downloaded: meteo_navarcles_201004.txt
# Downloaded: meteo_navarcles_201005.txt
# Downloaded: meteo_navarcles_201006.txt
# Downloaded: meteo_navarcles_201007.txt
# Downloaded: meteo_navarcles_201008.txt
# Downloaded: meteo_navarcles_201009.txt
# Downloaded: meteo_navarcles_201010.txt
# Downloaded: meteo_navarcles_201011.txt
# Downloaded: meteo_navarcles_201012.txt
# Fetching data for 2009...
# 2009 has 13 files
# Downloaded: meteo_navarcles_2009.txt
# Downloaded: meteo_navarcles_200901.txt
# Downloaded: meteo_navarcles_200902.txt
# Downloaded: meteo_navarcles_200903.txt
# Downloaded: meteo_navarcles_200904.txt
# Downloaded: meteo_navarcles_200905.txt
# Downloaded: meteo_navarcles_200906.txt
# Downloaded: meteo_navarcles_200907.txt
# Downloaded: meteo_navarcles_200908.txt
# Downloaded: meteo_navarcles_200909.txt
# Downloaded: meteo_navarcles_200910.txt
# Downloaded: meteo_navarcles_200911.txt
# Downloaded: meteo_navarcles_200912.txt
# Fetching data for 2008...
# 2008 has 10 files
# Downloaded: meteo_navarcles_2008.txt
# Downloaded: meteo_navarcles_200804.txt
# Downloaded: meteo_navarcles_200805.txt
# Downloaded: meteo_navarcles_200806.txt
# Downloaded: meteo_navarcles_200807.txt
# Downloaded: meteo_navarcles_200808.txt
# Downloaded: meteo_navarcles_200809.txt
# Downloaded: meteo_navarcles_200810.txt
# Downloaded: meteo_navarcles_200811.txt
# Downloaded: meteo_navarcles_200812.txt
# All files downloaded successfully.

# %%
# data for specific year
year = '2025'
year_link = year_links[year]
print(f"Fetching data for {year}...")
year_response = requests.get(year_link)
if year_response.status_code != 200:
    print(f"Failed to fetch year {year}.")

# Parse yearly summary page
year_soup = BeautifulSoup(year_response.text, "html.parser")

# Find all possible links to .txt files
txt_links = []
for file_link in year_soup.find_all("a", href=True):
    href = file_link["href"]
    if "media/repository/" in href and href.lower().endswith(".txt"):
        full_url = urljoin("https://www.navarcles.cat", href)
        txt_links.append(full_url)
print(f"{year} has {len(txt_links)} files")

for txt_link in txt_links:
    file_name = os.path.basename(txt_link)
    file_path = os.path.join(SAVE_DIR, file_name)

    # Download file
    file_response = requests.get(txt_link)
    if file_response.status_code == 200:
        with open(file_path, "wb") as f:
            f.write(file_response.content)
        print(f"Downloaded: {file_name}")
    else:
        print(f"Failed to download {file_name}")

print("All files downloaded successfully.")
# Out:
# Fetching data for 2025...
# 2025 has 4 files
# Downloaded: meteo_navarcles_202501.TXT
# Downloaded: meteo_navarcles_202504.TXT
# Downloaded: meteo_navarcles_202502.TXT
# Downloaded: meteo_navarcles_202503.TXT
# All files downloaded successfully.
